# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler

# %%
columns = ['user_id', 'movie_id', 'rating', 'timestamp']

df = pd.read_csv(r"C:\Users\Welcome\Downloads\archive (3)\ml-latest-small\movies.csv", sep='\t', names=columns)

df.head()
# Out:
#                                              user_id  movie_id  rating  \
# 0                               movieId,title,genres       NaN     NaN
# 1  1,Toy Story (1995),Adventure|Animation|Childre...       NaN     NaN
# 2        2,Jumanji (1995),Adventure|Children|Fantasy       NaN     NaN
# 3           3,Grumpier Old Men (1995),Comedy|Romance       NaN     NaN
# 4    4,Waiting to Exhale (1995),Comedy|Drama|Romance       NaN     NaN
#
#    timestamp
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Drop timestamp (not needed)
df = df.drop('timestamp', axis=1)

# Check dataset info
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9743 entries, 0 to 9742
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   9743 non-null   object
#  1   movie_id  0 non-null      float64
#  2   rating    0 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 228.5+ KB
# None
#        movie_id  rating
# count       0.0     0.0
# mean        NaN     NaN
# std         NaN     NaN
# min         NaN     NaN
# 25%         NaN     NaN
# 50%         NaN     NaN
# 75%         NaN     NaN
# max         NaN     NaN

# %%
user_item_matrix = df.pivot(index='user_id', columns='movie_id', values='rating')

user_item_matrix.head()
# Out:
# movie_id                                            NaN
# user_id
# 1,Toy Story (1995),Adventure|Animation|Children...  NaN
# 10,GoldenEye (1995),Action|Adventure|Thriller       NaN
# 100,City Hall (1996),Drama|Thriller                 NaN
# 100044,Human Planet (2011),Documentary              NaN
# 100068,Comme un chef (2012),Comedy                  NaN

# %%
# Mean centering
user_mean = user_item_matrix.mean(axis=1)

matrix_centered = user_item_matrix.sub(user_mean, axis=0)

# Fill NaN with 0 for SVD
matrix_centered = matrix_centered.fillna(0)

# %%
k = 20   # latent factors (can change later)

svd = TruncatedSVD(n_components=k, random_state=42)

U = svd.fit_transform(matrix_centered)
Sigma = svd.singular_values_
VT = svd.components_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 k = 20   # latent factors (can change later)
#       3 svd = TruncatedSVD(n_components=k, random_state=42)
# ----> 5 U = svd.fit_transform(matrix_centered)
#       6 Sigma = svd.singular_values_
#       7 VT = svd.components_
#
# File c:\Users\Welcome\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...
